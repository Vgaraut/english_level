# %%
import os
from thefuzz import fuzz
from thefuzz import process
import pandas as pd
import numpy as np
import re

# %%
folder = open('data_all\Subtitles_txt\my_big_fat_greek_wedding(2002).txt')

# %%
path = 'data_all\Subtitles_all'
idioms = open('1234.txt')

# %%
def find(source):
    path = source
    files = os.listdir(path)
    for file in files:
        temp = open(file)
        count=0
        if 
        os.rename(os.path.join(path, file), os.path.join(path, filename.lower() + file_extension))
        i+=1
    return f'{i} files renamed'

# %%
file = open('data_all\Subtitles_txt1\good_will_hunting(1997).txt')
data = file.readlines()
data = list(map(lambda s: s.strip(), data))
data
# Out:
# ['mod f x square  d x',
#  'so please finish percival for next time',
#  'i know many of you had this as undergraduates  but it won t hurt to brush up',
#  'thank you  steven',
#  'i also put an advanced fourier system on the main hallway chalkboard',
#  'i m hoping that one of you might prove it by the end of the semester',
#  'now the person to do so will not only be in my good graces',
#  'but also go on to fame and fortune',
#  'by having their accomplishment recorded and their name printed',
#  'in the auspicious m i t  tech',
#  'former winners include nobel laureates  field s medal winners',
#  'renowned astrophysicists and lowly m i t  professors',
#  'well  that s all  if you have any questions',
#  'i m sure that tom has the answers',
#  'hi  will',
#  'kirsten  how you doing    i m all right  how are you',
#  'good    i didn t get on cathy last night',
#  'no    no',
#  'why not    i don t know',
#  'cathy    what',
# ...

# %%
choices = ["Atlanta Falcons", "New York Jets", "New York Giants", "Dallas Cowboys"]
data= int(process.extractOne("cowboys", choices)[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=0'>1</a> choices = ["Atlanta Falcons", "New York Jets", "New York Giants", "Dallas Cowboys"]
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=1'>2</a> data= int(process.extractOne("cowboys", choices)[1])
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=2'>3</a> data.dtype
#
# AttributeError: 'int' object has no attribute 'dtype'

# %%
idioms = open('1234.txt')
idioms = idioms.readlines()
idioms = list(map(lambda s: s.strip(), idioms))

# %%
idioms = list(filter(None, idioms))
idioms
# Out:
# ['a bear with a sore head a bit of a dark horse',
#  "a bitter pill to swallow a different kettle of fish a dog's life",
#  'a fish out of water a long shot',
#  'a memory like a sieve a night owl',
#  'a pain in the neck a piece of cake',
#  'a red rag to a bull a red-letter day',
#  'a sitting duck',
#  'a storm in a teacup a wild-goose chase above board Achilles heel against all odds agree to disagree',
#  'all along',
#  'all but all in  all in all',
#  'all the same all told',
#  "an old wives' tale",
#  'an unknown quantity as a last resort',
#  'as the crow flies at close quarters at large',
#  "at the cutting edge bark up the wrong tree be ahead of one's time be all at sea",
#  'be all fingers and thumbs be all very well',
#  'be as busy as a bee be as thick as a brick',
#  'be beside oneself with anger be born yesterday',
#  'be broke',
#  'be caught red-handed be dying for sth',
#  'be fit for',
#  'be for the high jump be full of beans',
#  'be green',
# ...

# %%
clash = []
for i in range(len(idioms)):
    clash.append(process.extract(idioms[i], data, limit=50))

# %%
file = open('data_all\Subtitles_txt\my_big_fat_greek_wedding(2002).txt')

# %%
clash
# Out:
# [[('i know many of you had this as undergraduates  but it won t hurt to brush up',
#    86),
#   ('i m hoping that one of you might prove it by the end of the semester', 86),
#   ('she s missin  a tooth  will', 86),
#   ('you think i m afraid of you  you big fuck  you re crowdin  the fuckin  plate',
#    86),
#   ('hey  uh  casey s bouncin  up a bar at harvard next week  we should go up there',
#    86),
#   ('hey  morgan  who s the girl with the striped pants  she s got a nice ass',
#    86),
#   ('that guy used to beat the shit out of me in kindergarten    that guy', 86),
#   ('it s 15 minutes out of our way    what the fuck are we gonna do  we can t spare 15 minutes',
#    86),
#   ('chuck  i had a double burger', 86),
#   ('i said that when we pulled up  give me my sandwich and stop bein  a prick',
#    86),
#   ('we ll put you on a program  every day you come in here with your six cents',
#    86),
# ...
